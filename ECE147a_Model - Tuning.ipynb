# %%
import torch

# %%
if torch.cuda.is_available():
    print("CUDA Available: True")
    print(f"Number of GPUs: {torch.cuda.device_count()}")
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"PyTorch built with CUDA version: {torch.version.cuda}")
else:
    print("CUDA Available: False")
    print("PyTorch is likely using the CPU.")
# Out:
# CUDA Available: True
# Number of GPUs: 1
# GPU Name: NVIDIA GeForce RTX 4070 Laptop GPU
# PyTorch built with CUDA version: 12.1

# %%
# Single-user training for the custom LSTM on WSL
# baseline 20 epochs
# !python -m emg2qwerty.train \
  user="single_user" \
  module._target_="emg2qwerty.lstm_model.LSTMCTCModule" \
  ~module.block_channels \
  ~module.kernel_width \
  +module.hidden_size=256 \
  +module.num_layers=2 \
  optimizer.lr=0.002 \
  trainer.max_epochs=20 \
  trainer.accelerator=gpu \
  trainer.devices=1 \
  num_workers=4 \
  batch_size=16
# Out:
# [2026-03-11 14:28:46,554][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# 20 Epoch baseline - 256 -> 512 hidden size
# !python -m emg2qwerty.train \
  user="single_user" \
  module._target_="emg2qwerty.lstm_model.LSTMCTCModule" \
  ~module.block_channels \
  ~module.kernel_width \
  +module.hidden_size=512 \
  +module.num_layers=2 \
  optimizer.lr=0.002 \
  trainer.max_epochs=20 \
  trainer.accelerator=gpu \
  trainer.devices=1 \
  num_workers=4 \
  batch_size=16
# Out:
# [2026-03-11 14:59:32,381][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# 20 Epoch baseline - 256 -> 1024 hidden size
# !python -m emg2qwerty.train \
  user="single_user" \
  module._target_="emg2qwerty.lstm_model.LSTMCTCModule" \
  ~module.block_channels \
  ~module.kernel_width \
  +module.hidden_size=1024 \
  +module.num_layers=2 \
  optimizer.lr=0.002 \
  trainer.max_epochs=20 \
  trainer.accelerator=gpu \
  trainer.devices=1 \
  num_workers=4 \
  batch_size=16
# Out:
# [2026-03-11 16:05:29,146][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# 20 Epoch baseline - num_layers 2 -> 4
# !python -m emg2qwerty.train \
  user="single_user" \
  module._target_="emg2qwerty.lstm_model.LSTMCTCModule" \
  ~module.block_channels \
  ~module.kernel_width \
  +module.hidden_size=256 \
  +module.num_layers=4 \
  optimizer.lr=0.002 \
  trainer.max_epochs=20 \
  trainer.accelerator=gpu \
  trainer.devices=1 \
  num_workers=4 \
  batch_size=16
# Out:
# [2026-03-11 17:12:21,585][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# 20 Epoch baseline - num_layers 2 -> 1
# !python -m emg2qwerty.train \
  user="single_user" \
  module._target_="emg2qwerty.lstm_model.LSTMCTCModule" \
  ~module.block_channels \
  ~module.kernel_width \
  +module.hidden_size=256 \
  +module.num_layers=1 \
  optimizer.lr=0.002 \
  trainer.max_epochs=20 \
  trainer.accelerator=gpu \
  trainer.devices=1 \
  num_workers=4 \
  batch_size=16
# Out:
# [2026-03-12 17:48:30,811][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# 20 epochs - batch_size 16 -> 32
# !python -m emg2qwerty.train \
  user="single_user" \
  module._target_="emg2qwerty.lstm_model.LSTMCTCModule" \
  ~module.block_channels \
  ~module.kernel_width \
  +module.hidden_size=256 \
  +module.num_layers=2 \
  optimizer.lr=0.002 \
  trainer.max_epochs=20 \
  trainer.accelerator=gpu \
  trainer.devices=1 \
  num_workers=4 \
  batch_size=32
# Out:
# [2026-03-11 17:54:33,983][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# 20 epochs - learning rate 0.002 -> 0.001
# !python -m emg2qwerty.train \
  user="single_user" \
  module._target_="emg2qwerty.lstm_model.LSTMCTCModule" \
  ~module.block_channels \
  ~module.kernel_width \
  +module.hidden_size=256 \
  +module.num_layers=2 \
  optimizer.lr=0.001 \
  trainer.max_epochs=20 \
  trainer.accelerator=gpu \
  trainer.devices=1 \
  num_workers=4 \
  batch_size=16
# Out:
# [2026-03-11 21:23:47,777][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# 20 epochs - lr 0.002 -> 0.003
# !python -m emg2qwerty.train \
  user="single_user" \
  module._target_="emg2qwerty.lstm_model.LSTMCTCModule" \
  ~module.block_channels \
  ~module.kernel_width \
  +module.hidden_size=256 \
  +module.num_layers=2 \
  optimizer.lr=0.003 \
  trainer.max_epochs=20 \
  trainer.accelerator=gpu \
  trainer.devices=1 \
  num_workers=4 \
  batch_size=16
# Out:
# [2026-03-11 22:00:09,213][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Evaluate the trained Custom LSTM
# !python -m emg2qwerty.train \
  user="single_user" \
  module._target_="emg2qwerty.lstm_model.LSTMCTCModule" \
  ~module.block_channels \
  ~module.kernel_width \
  +module.hidden_size=256 \
  +module.num_layers=2 \
  checkpoint="logs/2026-03-11/14-28-46/checkpoints/last.ckpt" \
  train=False \
  trainer.accelerator=gpu \
  trainer.devices=1 \
  num_workers=4 \
  batch_size=16
# Out:
# [2026-03-11 14:49:05,585][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# 300 Epoch final test - 256 -> 512 hidden size
# !python -m emg2qwerty.train \
  user="single_user" \
  module._target_="emg2qwerty.lstm_model.LSTMCTCModule" \
  ~module.block_channels \
  ~module.kernel_width \
  +module.hidden_size=512 \
  +module.num_layers=2 \
  optimizer.lr=0.002 \
  trainer.max_epochs=300 \
  trainer.accelerator=gpu \
  trainer.devices=1 \
  num_workers=4 \
  batch_size=16
# Out:
# [2026-03-12 18:53:43,301][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs/2026-03-08/00-50-04/lightning_logs
# Out:
#       <iframe id="tensorboard-frame-634f146bde07eedb" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-634f146bde07eedb");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
